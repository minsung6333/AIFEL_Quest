# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np
 
import missingno as msno

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Exploratory Data Analysis

# %%
# Directory path
data_dir = '/aiffel/aiffel/AIFEL_Quest/Exploration_02/data'

# Dataset pwd
train_data_path = join(data_dir, 'train.csv')
test_data_path = join(data_dir, 'test.csv')

# Load Data
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)

# Check size of data
print("train_data Shape: ", train_data.shape)
print("test_data Shap: ", test_data.shape)
# Out:
# train_data Shape:  (15035, 21)
# test_data Shap:  (6468, 20)

# %%
train_data.head()
# Out:
#    id             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0   0  20141013T000000  221900.0         3       1.00         1180      5650
# 1   1  20150225T000000  180000.0         2       1.00          770     10000
# 2   2  20150218T000000  510000.0         3       2.00         1680      8080
# 3   3  20140627T000000  257500.0         3       2.25         1715      6819
# 4   4  20150115T000000  291850.0         3       1.50         1060      9711
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     1.0           0     0  ...      6         770              0      1933
# 2     1.0           0     0  ...      8        1680              0      1987
# 3     2.0           0     0  ...      7        1715              0      1995
# 4     1.0           0     0  ...      7        1060              0      1963
#
# ...

# %%
# Sepearate train_data
y = train_data['price']
del train_data['price']
print("y Shape: ",y.shape)
print(y.head())
# Out:
# y Shape:  (15035,)
# 0    221900.0
# 1    180000.0
# 2    510000.0
# 3    257500.0
# 4    291850.0
# Name: price, dtype: float64

# %%
# Concat dataset
# train_len = 15035
train_len = len(train_data)
data = pd.concat((train_data, test_data), axis=0)

print(len(data))
# Out:
# 21503

# %%
data.tail()
# Out:
#          id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 6463  21498  20140626T000000         3       1.75         1500     11968
# 6464  21499  20150126T000000         3       2.00         1490      1126
# 6465  21500  20150219T000000         3       2.50         1310      1294
# 6466  21501  20140623T000000         2       0.75         1020      1350
# 6467  21502  20150116T000000         3       2.50         1600      2388
#
#       floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 6463     1.0           0     0          3      6        1500              0
# 6464     3.0           0     0          3      8        1490              0
# 6465     2.0           0     0          3      8        1180            130
# 6466     2.0           0     0          3      7        1020              0
# 6467     2.0           0     0          3      8        1600              0
#
# ...

# %% [markdown]
# ## 1-1. Variables
# ID : 집을 구분하는 번호
# date : 집을 구매한 날짜
# price : 집의 가격(Target variable)
# bedrooms : 침실의 수
# bathrooms : 화장실의 수
# sqft_living : 주거 공간의 평방 피트(면적)
# sqft_lot : 부지의 평방 피트(면적)
# floors : 집의 층 수
# waterfront : 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)
# view : Has been viewed
# condition : 집의 전반적인 상태
# grade : King County grading 시스템 기준으로 매긴 집의 등급
# sqft_above : 지하실을 제외한 평방 피트(면적)
# sqft_basement : 지하실의 평방 피트(면적)
# yr_built : 지어진 년도
# yr_renovated : 집을 재건축한 년도
# zipcode : 우편번호
# lat : 위도
# long : 경도
# sqft_living15 : 2015년 기준 주거 공간의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)
# sqft_lot15 : 2015년 기준 주차 공간의 평방 피트(면적, 집을 재건축했다면, 변화가 있을 수 있음)

# %% [markdown]
# ## 1-2. Simple Preprocessing

# %% [markdown]
# ### Check missing values

# %%
# Visualization dataset
# missingno library : Black -> no outlier | White -> outlier exist
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
# Check closely
for col in data.columns:
    print('{} : {}'.format(col, len(data.loc[pd.isnull(data[col]), col].values)))
# Out:
# id : 0
# date : 0
# bedrooms : 0
# bathrooms : 0
# sqft_living : 0
# sqft_lot : 0
# floors : 0
# waterfront : 0
# view : 0
# condition : 0
# grade : 0
# sqft_above : 0
# sqft_basement : 0
# yr_built : 0
# yr_renovated : 0
# zipcode : 0
# lat : 0
# long : 0
# sqft_living15 : 0
# sqft_lot15 : 0

# %% [markdown]
# ### Delete id & Modify data vars

# %%
# Save test_data id to submit
test_data_id = data['id'][train_len:]

# Delete id
del data['id']

# Delete day, hour, min, sec
data['date'] = data['date'].apply(lambda x : str(x[:6])).astype(int)

# %%
data.head()
# Out:
#      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  201410         3       1.00         1180      5650     1.0           0
# 1  201502         2       1.00          770     10000     1.0           0
# 2  201502         3       2.00         1680      8080     1.0           0
# 3  201406         3       2.25         1715      6819     2.0           0
# 4  201501         3       1.50         1060      9711     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      6         770              0      1933             0
# 2     0          3      8        1680              0      1987             0
# 3     0          3      7        1715              0      1995             0
# 4     0          3      7        1060              0      1963             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
data.tail()
# Out:
#         date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 6463  201406         3       1.75         1500     11968     1.0           0
# 6464  201501         3       2.00         1490      1126     3.0           0
# 6465  201502         3       2.50         1310      1294     2.0           0
# 6466  201406         2       0.75         1020      1350     2.0           0
# 6467  201501         3       2.50         1600      2388     2.0           0
#
#       view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 6463     0          3      6        1500              0      2014
# 6464     0          3      8        1490              0      2014
# 6465     0          3      8        1180            130      2008
# 6466     0          3      7        1020              0      2009
# 6467     0          3      8        1600              0      2004
#
#       yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
data.reset_index(drop=True, inplace=True)
data.tail()
# Out:
#          date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 21498  201406         3       1.75         1500     11968     1.0           0
# 21499  201501         3       2.00         1490      1126     3.0           0
# 21500  201502         3       2.50         1310      1294     2.0           0
# 21501  201406         2       0.75         1020      1350     2.0           0
# 21502  201501         3       2.50         1600      2388     2.0           0
#
#        view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 21498     0          3      6        1500              0      2014
# 21499     0          3      8        1490              0      2014
# 21500     0          3      8        1180            130      2008
# 21501     0          3      7        1020              0      2009
# 21502     0          3      8        1600              0      2004
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# ### Delete columns

# %%
pd.unique(data['yr_renovated'])
# Out:
# array([   0, 2002, 1999, 1991, 1978, 2005, 2008, 2003, 1994, 1984, 1954,
#        2014, 2011, 1974, 1983, 2013, 1990, 1957, 1977, 1981, 1995, 2000,
#        1986, 1992, 2004, 2007, 1987, 2006, 1985, 1971, 1945, 1979, 1997,
#        2010, 1969, 1948, 2009, 1970, 2015, 1989, 2001, 1968, 2012, 1963,
#        1993, 1962, 1972, 1980, 1998, 1955, 1996, 1950, 1956, 1982, 1988,
#        1940, 1946, 1975, 1964, 1958, 1976, 1973, 1967, 1965, 1944, 1951,
#        1953, 1959, 1960, 1934])

# %%
data['yr_renovated-yr_built'] = data['yr_renovated'] - data['yr_built']

# %%
columns_to_drop = ['yr_renovated', 'yr_built']
data.drop(columns=columns_to_drop, inplace=True)

# %%
data.tail()
# Out:
#          date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 21498  201406         3       1.75         1500     11968     1.0           0
# 21499  201501         3       2.00         1490      1126     3.0           0
# 21500  201502         3       2.50         1310      1294     2.0           0
# 21501  201406         2       0.75         1020      1350     2.0           0
# 21502  201501         3       2.50         1600      2388     2.0           0
#
#        view  condition  grade  sqft_above  sqft_basement  zipcode      lat  \
# 21498     0          3      6        1500              0    98010  47.3095
# 21499     0          3      8        1490              0    98144  47.5699
# 21500     0          3      8        1180            130    98116  47.5773
# 21501     0          3      7        1020              0    98144  47.5944
# 21502     0          3      8        1600              0    98027  47.5345
#
# ...

# %%
data.shape
# Out:
# (21503, 18)

# %% [markdown]
# ### Check the distribution of each variable
# Skewed distributions towards one side can have a detrimental impact on the model's ability to make predictions, so they may need to be adjusted.

# %%
fig, ax = plt.subplots(9, 2, figsize=(20, 60))

# id 변수는 제외하고 분포를 확인합니다.
count = 0
columns = data.columns
for row in range(10):
    for col in range(2):
        sns.kdeplot(data[columns[count]], ax=ax[row][col])
        ax[row][col].set_title(columns[count], fontsize=15)
        count+=1
        if count == 19 :
            break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_282/242517767.py in <module>
#       6 for row in range(10):
#       7     for col in range(2):
# ----> 8         sns.kdeplot(data[columns[count]], ax=ax[row][col])
#       9         ax[row][col].set_title(columns[count], fontsize=15)
#      10         count+=1
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: index 18 is out of bounds for axis 0 with size 18

# %% [markdown]
# ### Normalization

# %%
skew_columns = ['bedrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']

# log-scaling
for c in skew_columns:
    data[c] = np.log1p(data[c].values)

# %%
fig, ax = plt.subplots(3, 2, figsize=(10, 15))

count = 0
for row in range(3):
    for col in range(2):
        if count == 5:
            break
        sns.kdeplot(data[skew_columns[count]], ax=ax[row][col])
        ax[row][col].set_title(skew_columns[count], fontsize=15)
        count+=1

# %%
sub = data.iloc[train_len:, :]
X = data.iloc[:train_len, :]

print("sub Shape: ", sub.shape)
print("X Shap: ", X.shape)
# Out:
# sub Shape:  (6468, 18)
# X Shap:  (15035, 18)

# %%
# Price plot
f, ax = plt.subplots(figsize=(8,6))
sns.distplot(y)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# **타겟 값이 치추쳐 있기 때문에, 정규화를 시켜줘야 한다**

# %%
# Nomalization price
y = np.log1p(y)
f, ax = plt.subplots(figsize=(8,6))
sns.distplot(y)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
y
# Out:
# 0        12.309987
# 1        12.100718
# 2        13.142168
# 3        12.458779
# 4        12.583999
#            ...
# 15030    13.322338
# 15031    13.822984
# 15032    12.793862
# 15033    12.899222
# 15034    12.691584
# Name: price, Length: 15035, dtype: float64

# %% [markdown]
# # 2. Model

# %%
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

random_state=2020        

xgboost = XGBRegressor(random_state=random_state)
lightgbm = LGBMRegressor(random_state=random_state)
rdforest = RandomForestRegressor(random_state=random_state)

models = [xgboost, lightgbm, rdforest]

# %% [markdown]
# ## Hyper Parameter

# %%
from sklearn.model_selection import GridSearchCV

# Hyper Parameter 
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [1, 10, 20, 30],
}

# GridSearchCV Function -> Hyperparameter tuning
# Return the RMSLE data with param
def my_GridSearch(model, train, y, param_grid, verbose=2, n_jobs=5):
    # GridSearchCV
    grid_model = GridSearchCV(model, param_grid=param_grid, scoring='neg_mean_squared_error', \
                              cv=5, verbose=verbose, n_jobs=n_jobs)
    
    # fitting
    grid_model.fit(train, y)

    # 결과값 저장
    params = grid_model.cv_results_['params']
    score = grid_model.cv_results_['mean_test_score']
    
    # 데이터 프레임 생성
    results = pd.DataFrame(params)
    results['score'] = score
    
    # RMSLE 값 계산 후 정렬
    results['RMSLE'] = np.sqrt(-1 * results['score'])
    results = results.sort_values('RMSLE')

    return results

# %%
def save_submission(model, train, y, test, model_name, rmsle=None):
    model.fit(train, y)
    prediction = model.predict(test)
    prediction = np.expm1(prediction)
    data_dir = '/aiffel/aiffel/AIFEL_Quest/Exploration_02/data'
    submission_path = join(data_dir, 'sample_submission.csv')
    submission = pd.read_csv(submission_path)
    submission['price'] = prediction
    submission_csv_path = '{}/submission_{}_RMSLE_{}.csv'.format(data_dir, model_name, rmsle)
    submission.to_csv(submission_csv_path, index=False)
    print('{} saved!'.format(submission_csv_path))

# %%
model = LGBMRegressor(random_state=random_state)
my_GridSearch(model, X, y, param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
#    max_depth  n_estimators     score     RMSLE
# 5         20           100 -0.027123  0.164692
# 7         30           100 -0.027123  0.164692
# 3         10           100 -0.027236  0.165033
# 4         20            50 -0.029281  0.171117
# 6         30            50 -0.029281  0.171117
# 2         10            50 -0.029325  0.171244
# 1          1           100 -0.054620  0.233709
# 0          1            50 -0.073401  0.270927

# %%
XGB_param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [1, 10],
}
model = XGBRegressor(random_state=random_state)
my_GridSearch(model, X, y, XGB_param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# /opt/conda/lib/python3.9/site-packages/pkg_resources/__init__.py:122: PkgResourcesDeprecationWarning: 0.996-ko-0.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/pkg_resources/__init__.py:122: PkgResourcesDeprecationWarning: 0.996-ko-0.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/pkg_resources/__init__.py:122: PkgResourcesDeprecationWarning: 0.996-ko-0.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/pkg_resources/__init__.py:122: PkgResourcesDeprecationWarning: 0.996-ko-0.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# ...

# %%
model = RandomForestRegressor(random_state=random_state)
my_GridSearch(model, X, y, param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
#    max_depth  n_estimators     score     RMSLE
# 3         10           100 -0.035227  0.187688
# 2         10            50 -0.035430  0.188228
# 1          1           100 -0.179128  0.423235
# 0          1            50 -0.179746  0.423965

# %%
model = LGBMRegressor(max_depth=10, n_estimators=100, random_state=random_state)
save_submission(model, X, y, sub, 'lgbm', rmsle='0.164692')
# Out:
# /aiffel/aiffel/AIFEL_Quest/Exploration_02/data/submission_lgbm_RMSLE_0.164692.csv saved!
# [CV] END .......................max_depth=1, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   1.6s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.9s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.9s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   1.5s
# [CV] END ......................max_depth=30, n_estimators=50; total time=   0.9s
# [CV] END .....................max_depth=30, n_estimators=100; total time=   1.4s
# [CV] END .......................max_depth=1, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=1, n_estimators=100; total time=   0.6s
# ...

# %% [markdown]
# # 1차 제출
# Follow the Aiffel node
# ![Screenshot](screenshot_01.png)

# %% [markdown]
# # 2차 제출
#
# ![Screenshot](screenshot_02.png)

# %% [markdown]
# # Project Rubric
# 데이터 전처리, 모델학습, 예측의 전체 과정을 거쳐 캐글 submission까지 전과정이 성공적으로 진행되었는가? -> O
# 제출된 노트북이 캐글 커널로 사용될 수 있을 만큼 전처리, 학습, 최적화 진행 과정이 체계적으로 기술되었는가? -> O
# 다양한 피처 엔지니어링과 하이퍼 파라미터 튜닝 등의 최적화 기법을 통해 캐글 리더보드의 Private score 기준 110000 이하의 점수를 얻었는가? -> X
